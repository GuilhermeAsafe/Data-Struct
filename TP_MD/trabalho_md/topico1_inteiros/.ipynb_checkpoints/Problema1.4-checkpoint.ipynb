# %%
n = 48
D48 = [d for d in range(1, n + 1) if n % d == 0]
tau_48 = len(D48)
sigma_48 = sum(D48)

print(f"Para n = {n}:")
print(f"Número de divisores (tau): {tau_48}")
print(f"Soma dos divisores (sigma): {sigma_48}\n")

m = 150
D150 = [d for d in range(1, m + 1) if m % d == 0]
tau_150 = len(D150)
sigma_150 = sum(D150)

print(f"Para m = {m}:")
print(f"Número de divisores (tau): {tau_150}")
print(f"Soma dos divisores (sigma): {sigma_150}")
# Out:
# --- Propriedades para n = 48 ---
# Lista de Divisores: [1, 2, 3, 4, 6, 8, 12, 16, 24, 48]
# Número de Divisores (tau): 10
# Soma Total dos Divisores (sigma): 124
# Soma dos Divisores Próprios: 76
# É número perfeito? False
#
# --- Propriedades para n = 150 ---
# Lista de Divisores: [1, 2, 3, 5, 6, 10, 15, 25, 30, 50, 75, 150]
# Número de Divisores (tau): 12
# Soma Total dos Divisores (sigma): 372
# Soma dos Divisores Próprios: 222
# É número perfeito? False
# ([1, 2, 3, 5, 6, 10, 15, 25, 30, 50, 75, 150], 12, 372, 222)
