# %%
def entrada():
    #para b diferente de zero vale
    b = int(input())
    return b

# %%
def b_divide_zero():
    b = entrada()
    if (0%b == 0):
        return True
    else:
        return False

# %%
b_divide_zero()
